# %% [markdown]
# <a href="https://colab.research.google.com/github/midnightripper/testing/blob/main/Simplified_CNN2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pip install tensorflow-addons
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorflow-addons
#   Downloading tensorflow_addons-0.19.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 24.0 MB/s eta 0:00:00
# Collecting typeguard>=2.7
#   Downloading typeguard-3.0.2-py3-none-any.whl (30 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from tensorflow-addons) (23.0)
# Requirement already satisfied: importlib-metadata>=3.6 in /usr/local/lib/python3.9/dist-packages (from typeguard>=2.7->tensorflow-addons) (6.1.0)
# Requirement already satisfied: typing-extensions>=4.4.0 in /usr/local/lib/python3.9/dist-packages (from typeguard>=2.7->tensorflow-addons) (4.5.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.9/dist-packages (from importlib-metadata>=3.6->typeguard>=2.7->tensorflow-addons) (3.15.0)
# Installing collected packages: typeguard, tensorflow-addons
# Successfully installed tensorflow-addons-0.19.0 typeguard-3.0.2

# %%
import tensorflow as tf
import tensorflow_addons as tfa
import numpy as np
from tensorflow import keras
from tensorflow.keras import layers
import scipy.io as sio
import pandas as pd
import matplotlib.pyplot as plt
from tensorflow.keras.models import Model
# Out:
# /usr/local/lib/python3.9/dist-packages/tensorflow_addons/utils/ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.9.0 and strictly below 2.12.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.12.0 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(

# %%
GER_test = (np.array(sio.loadmat('/content/drive/MyDrive/training data/GER_test.mat')['GER_test'])).transpose()
GER_train = (np.array(sio.loadmat('/content/drive/MyDrive/training data/GER_train.mat')['GER_train'])).transpose()
test_frame = pd.DataFrame(GER_test).sort_values(1)
train_frame = pd.DataFrame(GER_train).sort_values(1)

# %%
print(f"x_train shape: {GER_train.shape} - y_train shape: {GER_train.shape}")
print(f"x_test shape: {GER_test.shape} - y_test shape: {GER_test.shape}")
# Out:
# x_train shape: (6981, 21) - y_train shape: (6981, 21)
# x_test shape: (6248, 21) - y_test shape: (6248, 21)

# %%
def get_data_labels(split):
    x = pd.DataFrame(split)
    labels = x[0].values.astype(np.uint8)
    del x[0],x[1]
    data = x.values 
    return data, labels

x_train, y_train = get_data_labels(train_frame.values.tolist())
x_test, y_test = get_data_labels(test_frame.values.tolist())

# %%
input_shape=(19,)
num_classes = 2

# %%
from keras.models import Sequential
from keras.layers import Activation
from keras.layers import Input
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense

learning_rate = 0.001
batch_size = 265
hidden_units = 32
projection_units = 128
num_epochs = 100
dropout_rate = 0.5
temperature = 0.05

# %%
def create_classifier():
  model = Sequential()
  model.add(Conv1D(filters=128, kernel_size=3, activation='relu', input_shape=(19,1)))
  model.add(MaxPooling1D(pool_size=2))
  model.add(Conv1D(filters=64, kernel_size=3, activation='relu'))
  model.add(MaxPooling1D(pool_size=2))
  model.add(Flatten())
  model.add(Dense(32, activation='relu'))
  model.add(Dense(1, activation='sigmoid'))
  model.compile(
        optimizer=keras.optimizers.Adam(learning_rate),
        loss=keras.losses.BinaryCrossentropy(from_logits=True),
        metrics=[keras.metrics.BinaryAccuracy()],
    )
  return model

# %%
def create_classifier():
  model = Sequential()
  model.add(Conv1D(filters=32, kernel_size=4, activation='relu', input_shape=(19,1)))
  model.add(MaxPooling1D(pool_size=1))
  model.add(Conv1D(filters=64, kernel_size=3, activation='relu'))
  model.add(MaxPooling1D(pool_size=1))
  model.add(Conv1D(filters=128, kernel_size=2, activation='relu'))
  model.add(MaxPooling1D(pool_size=1))
  model.add(tf.keras.layers.Dropout(0.5))
  model.add(Conv1D(filters=256, kernel_size=2, activation='relu'))
  model.add(MaxPooling1D(pool_size=1))
  # model.add(Conv1D(filters=64, kernel_size=2, activation='relu'))
  # model.add(MaxPooling1D(pool_size=1))

  # model.add(Conv1D(filters=128, kernel_size=2, activation='relu'))
  # model.add(MaxPooling1D(pool_size=2))
  # model.add(Conv1D(filters=128, kernel_size=2, activation='relu'))
  # model.add(MaxPooling1D(pool_size=2))
  # model.add(tf.keras.layers.Dropout(0.5))
  
  # model.add(Conv1D(filters=256, kernel_size=5, activation='relu'))
  # model.add(MaxPooling1D(pool_size=2))
  # model.add(Conv1D(filters=256, kernel_size=5, activation='relu'))
  # model.add(MaxPooling1D(pool_size=2))
  # model.add(tf.keras.layers.Dropout(0.5))

  # model.add(Conv1D(filters=256, kernel_size=5, activation='relu'))
  # model.add(MaxPooling1D(pool_size=2))
  # model.add(tf.keras.layers.Dropout(0.5))
  # model.add(Conv1D(filters=256, kernel_size=5, activation='relu'))
  # model.add(MaxPooling1D(pool_size=2))
  model.add(Flatten())

  model.add(Dense(128, activation='relu'))
  model.add(tf.keras.layers.Dropout(0.5))
  model.add(Dense(64, activation='relu'))
  model.add(tf.keras.layers.Dropout(0.5))
  model.add(Dense(32, activation='relu'))
  model.add(Dense(8, activation='relu'))
  model.add(Dense(1, activation='sigmoid'))
  # model.compile(
  #       optimizer=keras.optimizers.Adam(learning_rate),
  #       loss=keras.losses.BinaryCrossentropy(from_logits=True),
  #       metrics=[keras.metrics.BinaryAccuracy()],
  #   )
  model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
  return model

# %%
# encoder = create_encoder()
classifier = create_classifier()
classifier.summary()

history = classifier.fit(x=x_train, y=y_train, batch_size=batch_size, epochs=num_epochs)

accuracy = classifier.evaluate(x_test, y_test)[1]
print(f"Test accuracy: {round(accuracy * 100, 2)}%")
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_16 (Conv1D)          (None, 16, 32)            160
#
#  max_pooling1d_16 (MaxPoolin  (None, 16, 32)           0
#  g1D)
#
#  conv1d_17 (Conv1D)          (None, 14, 64)            6208
#
#  max_pooling1d_17 (MaxPoolin  (None, 14, 64)           0
#  g1D)
#
#  conv1d_18 (Conv1D)          (None, 13, 128)           16512
#
#  max_pooling1d_18 (MaxPoolin  (None, 13, 128)          0
#  g1D)
#
#  dropout_3 (Dropout)         (None, 13, 128)           0
#
#  conv1d_19 (Conv1D)          (None, 12, 256)           65792
#
#  max_pooling1d_19 (MaxPoolin  (None, 12, 256)          0
#  g1D)
#
#  flatten_4 (Flatten)         (None, 3072)              0
#
#  dense_10 (Dense)            (None, 128)               393344
#
#  dropout_4 (Dropout)         (None, 128)               0
#
#  dense_11 (Dense)            (None, 64)                8256
#
#  dropout_5 (Dropout)         (None, 64)                0
#
#  dense_12 (Dense)            (None, 32)                2080
#
#  dense_13 (Dense)            (None, 8)                 264
#
#  dense_14 (Dense)            (None, 1)                 9
#
# =================================================================
# Total params: 492,625
# Trainable params: 492,625
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 27/27 [==============================] - 6s 139ms/step - loss: 0.6889 - accuracy: 0.5264
# Epoch 2/100
# 27/27 [==============================] - 3s 94ms/step - loss: 0.6319 - accuracy: 0.6576
# Epoch 3/100
# 27/27 [==============================] - 2s 80ms/step - loss: 0.5780 - accuracy: 0.7185
# Epoch 4/100
# 27/27 [==============================] - 2s 81ms/step - loss: 0.5455 - accuracy: 0.7356
# Epoch 5/100
# 27/27 [==============================] - 2s 79ms/step - loss: 0.5098 - accuracy: 0.7550
# Epoch 6/100
# 27/27 [==============================] - 2s 87ms/step - loss: 0.4996 - accuracy: 0.7659
# Epoch 7/100
# 27/27 [==============================] - 4s 142ms/step - loss: 0.5015 - accuracy: 0.7652
# Epoch 8/100
# 27/27 [==============================] - 2s 83ms/step - loss: 0.4892 - accuracy: 0.7707
# Epoch 9/100
# 27/27 [==============================] - 2s 79ms/step - loss: 0.4844 - accuracy: 0.7767
# Epoch 10/100
# 27/27 [==============================] - 2s 79ms/step - loss: 0.4785 - accuracy: 0.7784
# Epoch 11/100
# 27/27 [==============================] - 2s 80ms/step - loss: 0.4788 - accuracy: 0.7781
# Epoch 12/100
# 27/27 [==============================] - 2s 93ms/step - loss: 0.4724 - accuracy: 0.7877
# Epoch 13/100
# 27/27 [==============================] - 4s 139ms/step - loss: 0.4686 - accuracy: 0.7831
# Epoch 14/100
# 27/27 [==============================] - 2s 79ms/step - loss: 0.4620 - accuracy: 0.7916
# Epoch 15/100
# 27/27 [==============================] - 2s 79ms/step - loss: 0.4588 - accuracy: 0.7890
# Epoch 16/100
# 27/27 [==============================] - 2s 80ms/step - loss: 0.4583 - accuracy: 0.7911
# Epoch 17/100
# 27/27 [==============================] - 2s 80ms/step - loss: 0.4569 - accuracy: 0.7942
# Epoch 18/100
# 27/27 [==============================] - 3s 105ms/step - loss: 0.4618 - accuracy: 0.7937
# Epoch 19/100
# 27/27 [==============================] - 3s 127ms/step - loss: 0.4509 - accuracy: 0.7899
# Epoch 20/100
# 27/27 [==============================] - 2s 79ms/step - loss: 0.4438 - accuracy: 0.8000
# Epoch 21/100
# 27/27 [==============================] - 2s 83ms/step - loss: 0.4450 - accuracy: 0.8003
# Epoch 22/100
# 27/27 [==============================] - 2s 80ms/step - loss: 0.4395 - accuracy: 0.8030
# Epoch 23/100
# 27/27 [==============================] - 2s 81ms/step - loss: 0.4429 - accuracy: 0.7969
# Epoch 24/100
# 27/27 [==============================] - 3s 117ms/step - loss: 0.4404 - accuracy: 0.8036
# Epoch 25/100
# 27/27 [==============================] - 3s 116ms/step - loss: 0.4402 - accuracy: 0.7940
# Epoch 26/100
# 27/27 [==============================] - 2s 80ms/step - loss: 0.4355 - accuracy: 0.8023
# Epoch 27/100
# 27/27 [==============================] - 3s 97ms/step - loss: 0.4354 - accuracy: 0.8033
# Epoch 28/100
# 27/27 [==============================] - 2s 81ms/step - loss: 0.4333 - accuracy: 0.8049
# Epoch 29/100
# 27/27 [==============================] - 4s 146ms/step - loss: 0.4286 - accuracy: 0.8093
# Epoch 30/100
# 27/27 [==============================] - 5s 197ms/step - loss: 0.4247 - accuracy: 0.8118
# Epoch 31/100
# 27/27 [==============================] - 2s 84ms/step - loss: 0.4282 - accuracy: 0.8101
# Epoch 32/100
# 27/27 [==============================] - 2s 82ms/step - loss: 0.4306 - accuracy: 0.8096
# Epoch 33/100
# 27/27 [==============================] - 2s 80ms/step - loss: 0.4217 - accuracy: 0.8111
# Epoch 34/100
# 27/27 [==============================] - 2s 80ms/step - loss: 0.4219 - accuracy: 0.8112
# Epoch 35/100
# 27/27 [==============================] - 3s 100ms/step - loss: 0.4276 - accuracy: 0.8121
# Epoch 36/100
# 27/27 [==============================] - 4s 134ms/step - loss: 0.4224 - accuracy: 0.8121
# Epoch 37/100
# 27/27 [==============================] - 2s 81ms/step - loss: 0.4156 - accuracy: 0.8165
# Epoch 38/100
# 27/27 [==============================] - 2s 80ms/step - loss: 0.4152 - accuracy: 0.8164
# Epoch 39/100
# 27/27 [==============================] - 2s 80ms/step - loss: 0.4134 - accuracy: 0.8164
# Epoch 40/100
# 27/27 [==============================] - 2s 82ms/step - loss: 0.4101 - accuracy: 0.8189
# Epoch 41/100
# 27/27 [==============================] - 3s 115ms/step - loss: 0.4190 - accuracy: 0.8162
# Epoch 42/100
# 27/27 [==============================] - 4s 159ms/step - loss: 0.4130 - accuracy: 0.8219
# Epoch 43/100
# 27/27 [==============================] - 2s 81ms/step - loss: 0.4067 - accuracy: 0.8207
# Epoch 44/100
# 27/27 [==============================] - 2s 81ms/step - loss: 0.4047 - accuracy: 0.8166
# Epoch 45/100
# 27/27 [==============================] - 2s 77ms/step - loss: 0.4040 - accuracy: 0.8231
# Epoch 46/100
# 27/27 [==============================] - 2s 83ms/step - loss: 0.4070 - accuracy: 0.8217
# Epoch 47/100
# 27/27 [==============================] - 4s 143ms/step - loss: 0.4066 - accuracy: 0.8208
# Epoch 48/100
# 27/27 [==============================] - 2s 88ms/step - loss: 0.4039 - accuracy: 0.8181
# Epoch 49/100
# 27/27 [==============================] - 2s 80ms/step - loss: 0.4032 - accuracy: 0.8195
# Epoch 50/100
# 27/27 [==============================] - 2s 79ms/step - loss: 0.4089 - accuracy: 0.8197
# Epoch 51/100
# 27/27 [==============================] - 2s 79ms/step - loss: 0.3996 - accuracy: 0.8214
# Epoch 52/100
# 27/27 [==============================] - 2s 93ms/step - loss: 0.3963 - accuracy: 0.8282
# Epoch 53/100
# 27/27 [==============================] - 4s 140ms/step - loss: 0.3978 - accuracy: 0.8284
# Epoch 54/100
# 27/27 [==============================] - 2s 78ms/step - loss: 0.3972 - accuracy: 0.8271
# Epoch 55/100
# 27/27 [==============================] - 2s 78ms/step - loss: 0.4032 - accuracy: 0.8189
# Epoch 56/100
# 27/27 [==============================] - 2s 79ms/step - loss: 0.3995 - accuracy: 0.8215
# Epoch 57/100
# 27/27 [==============================] - 2s 79ms/step - loss: 0.3972 - accuracy: 0.8238
# Epoch 58/100
# 27/27 [==============================] - 3s 95ms/step - loss: 0.4050 - accuracy: 0.8222
# Epoch 59/100
# 27/27 [==============================] - 4s 138ms/step - loss: 0.4012 - accuracy: 0.8218
# Epoch 60/100
# 27/27 [==============================] - 2s 81ms/step - loss: 0.3945 - accuracy: 0.8287
# Epoch 61/100
# 27/27 [==============================] - 2s 82ms/step - loss: 0.3926 - accuracy: 0.8278
# Epoch 62/100
# 27/27 [==============================] - 2s 82ms/step - loss: 0.3883 - accuracy: 0.8311
# Epoch 63/100
# 27/27 [==============================] - 2s 81ms/step - loss: 0.3914 - accuracy: 0.8301
# Epoch 64/100
# 27/27 [==============================] - 3s 112ms/step - loss: 0.3894 - accuracy: 0.8323
# Epoch 65/100
# 27/27 [==============================] - 3s 125ms/step - loss: 0.3931 - accuracy: 0.8278
# Epoch 66/100
# 27/27 [==============================] - 2s 82ms/step - loss: 0.3874 - accuracy: 0.8307
# Epoch 67/100
# 27/27 [==============================] - 2s 81ms/step - loss: 0.3892 - accuracy: 0.8303
# Epoch 68/100
# 27/27 [==============================] - 2s 80ms/step - loss: 0.3933 - accuracy: 0.8265
# Epoch 69/100
# 27/27 [==============================] - 2s 80ms/step - loss: 0.3845 - accuracy: 0.8357
# Epoch 70/100
# 27/27 [==============================] - 4s 131ms/step - loss: 0.3893 - accuracy: 0.8272
# Epoch 71/100
# 27/27 [==============================] - 3s 120ms/step - loss: 0.3837 - accuracy: 0.8343
# Epoch 72/100
# 27/27 [==============================] - 2s 88ms/step - loss: 0.3847 - accuracy: 0.8323
# Epoch 73/100
# 27/27 [==============================] - 5s 174ms/step - loss: 0.3877 - accuracy: 0.8288
# Epoch 74/100
# 27/27 [==============================] - 8s 294ms/step - loss: 0.3864 - accuracy: 0.8297
# Epoch 75/100
# 27/27 [==============================] - 5s 193ms/step - loss: 0.3843 - accuracy: 0.8301
# Epoch 76/100
# 27/27 [==============================] - 5s 199ms/step - loss: 0.3818 - accuracy: 0.8334
# Epoch 77/100
# 27/27 [==============================] - 6s 209ms/step - loss: 0.3792 - accuracy: 0.8350
# Epoch 78/100
# 27/27 [==============================] - 5s 177ms/step - loss: 0.3863 - accuracy: 0.8341
# Epoch 79/100
# 27/27 [==============================] - 4s 137ms/step - loss: 0.3798 - accuracy: 0.8368
# Epoch 80/100
# 27/27 [==============================] - 6s 210ms/step - loss: 0.3756 - accuracy: 0.8367
# Epoch 81/100
# 27/27 [==============================] - 3s 101ms/step - loss: 0.3882 - accuracy: 0.8293
# Epoch 82/100
# 27/27 [==============================] - 2s 81ms/step - loss: 0.3712 - accuracy: 0.8407
# Epoch 83/100
# 27/27 [==============================] - 3s 106ms/step - loss: 0.3841 - accuracy: 0.8374
# Epoch 84/100
# 27/27 [==============================] - 6s 237ms/step - loss: 0.3786 - accuracy: 0.8330
# Epoch 85/100
# 27/27 [==============================] - 4s 128ms/step - loss: 0.3763 - accuracy: 0.8380
# Epoch 86/100
# 27/27 [==============================] - 2s 83ms/step - loss: 0.3731 - accuracy: 0.8397
# Epoch 87/100
# 27/27 [==============================] - 2s 78ms/step - loss: 0.3770 - accuracy: 0.8367
# Epoch 88/100
# 27/27 [==============================] - 2s 79ms/step - loss: 0.3751 - accuracy: 0.8364
# Epoch 89/100
# 27/27 [==============================] - 4s 137ms/step - loss: 0.3761 - accuracy: 0.8331
# Epoch 90/100
# 27/27 [==============================] - 3s 95ms/step - loss: 0.3739 - accuracy: 0.8353
# Epoch 91/100
# 27/27 [==============================] - 2s 81ms/step - loss: 0.3787 - accuracy: 0.8330
# Epoch 92/100
# 27/27 [==============================] - 2s 80ms/step - loss: 0.3723 - accuracy: 0.8378
# Epoch 93/100
# 27/27 [==============================] - 2s 81ms/step - loss: 0.3607 - accuracy: 0.8474
# Epoch 94/100
# 27/27 [==============================] - 2s 91ms/step - loss: 0.3712 - accuracy: 0.8387
# Epoch 95/100
# 27/27 [==============================] - 4s 144ms/step - loss: 0.3719 - accuracy: 0.8383
# Epoch 96/100
# 27/27 [==============================] - 2s 81ms/step - loss: 0.3686 - accuracy: 0.8423
# Epoch 97/100
# 27/27 [==============================] - 2s 81ms/step - loss: 0.3755 - accuracy: 0.8374
# Epoch 98/100
# 27/27 [==============================] - 2s 81ms/step - loss: 0.3728 - accuracy: 0.8377
# Epoch 99/100
# 27/27 [==============================] - 2s 80ms/step - loss: 0.3726 - accuracy: 0.8373
# Epoch 100/100
# 27/27 [==============================] - 3s 107ms/step - loss: 0.3647 - accuracy: 0.8469
# 196/196 [==============================] - 1s 6ms/step - loss: 0.3857 - accuracy: 0.8302
# Test accuracy: 83.02%

# %%
accuracy = classifier.evaluate(x_train, y_train)[1]
print(f"Test accuracy: {round(accuracy * 100, 2)}%")
# Out:
# 219/219 [==============================] - 1s 7ms/step - loss: 0.3372 - accuracy: 0.8595
# Test accuracy: 85.95%

# %%
def create_classifier():
  model = Sequential()
  model.add(Conv1D(filters=64, kernel_size=2, activation='relu', input_shape=(19,1)))
  model.add(MaxPooling1D(pool_size=1))
  model.add(tf.keras.layers.Dropout(0.5))
  model.add(Conv1D(filters=32, kernel_size=2, activation='relu'))
  model.add(MaxPooling1D(pool_size=1))
  # model.add(Conv1D(filters=64, kernel_size=2, activation='relu'))
  # model.add(MaxPooling1D(pool_size=1))

  # model.add(Conv1D(filters=128, kernel_size=2, activation='relu'))
  # model.add(MaxPooling1D(pool_size=2))
  # model.add(Conv1D(filters=128, kernel_size=2, activation='relu'))
  # model.add(MaxPooling1D(pool_size=2))
  # model.add(tf.keras.layers.Dropout(0.5))
  
  # model.add(Conv1D(filters=256, kernel_size=5, activation='relu'))
  # model.add(MaxPooling1D(pool_size=2))
  # model.add(Conv1D(filters=256, kernel_size=5, activation='relu'))
  # model.add(MaxPooling1D(pool_size=2))
  # model.add(tf.keras.layers.Dropout(0.5))

  # model.add(Conv1D(filters=256, kernel_size=5, activation='relu'))
  # model.add(MaxPooling1D(pool_size=2))
  # model.add(tf.keras.layers.Dropout(0.5))
  # model.add(Conv1D(filters=256, kernel_size=5, activation='relu'))
  # model.add(MaxPooling1D(pool_size=2))
  model.add(Flatten())

  model.add(Dense(128, activation='relu'))
  model.add(tf.keras.layers.Dropout(0.5))
  model.add(Dense(64, activation='relu'))
  model.add(tf.keras.layers.Dropout(0.5))
  model.add(Dense(32, activation='relu'))
  model.add(Dense(8, activation='relu'))
  model.add(Dense(1, activation='sigmoid'))
  # model.compile(
  #       optimizer=keras.optimizers.Adam(learning_rate),
  #       loss=keras.losses.BinaryCrossentropy(from_logits=True),
  #       metrics=[keras.metrics.BinaryAccuracy()],
  #   )
  model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
  return model

# %%
# encoder = create_encoder()
classifier = create_classifier()
classifier.summary()

history = classifier.fit(x=x_train, y=y_train, batch_size=batch_size, epochs=num_epochs)

accuracy = classifier.evaluate(x_test, y_test)[1]
print(f"Test accuracy: {round(accuracy * 100, 2)}%")
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_24 (Conv1D)          (None, 18, 64)            192
#
#  max_pooling1d_24 (MaxPoolin  (None, 18, 64)           0
#  g1D)
#
#  dropout_9 (Dropout)         (None, 18, 64)            0
#
#  conv1d_25 (Conv1D)          (None, 17, 32)            4128
#
#  max_pooling1d_25 (MaxPoolin  (None, 17, 32)           0
#  g1D)
#
#  flatten_6 (Flatten)         (None, 544)               0
#
#  dense_20 (Dense)            (None, 128)               69760
#
#  dropout_10 (Dropout)        (None, 128)               0
#
#  dense_21 (Dense)            (None, 64)                8256
#
#  dropout_11 (Dropout)        (None, 64)                0
#
#  dense_22 (Dense)            (None, 32)                2080
#
#  dense_23 (Dense)            (None, 8)                 264
#
#  dense_24 (Dense)            (None, 1)                 9
#
# =================================================================
# Total params: 84,689
# Trainable params: 84,689
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 27/27 [==============================] - 3s 41ms/step - loss: 0.7002 - accuracy: 0.4860
# Epoch 2/100
# 27/27 [==============================] - 1s 35ms/step - loss: 0.6742 - accuracy: 0.5936
# Epoch 3/100
# 27/27 [==============================] - 1s 23ms/step - loss: 0.6386 - accuracy: 0.6399
# Epoch 4/100
# 27/27 [==============================] - 1s 23ms/step - loss: 0.5900 - accuracy: 0.6970
# Epoch 5/100
# 27/27 [==============================] - 1s 22ms/step - loss: 0.5573 - accuracy: 0.7283
# Epoch 6/100
# 27/27 [==============================] - 1s 24ms/step - loss: 0.5523 - accuracy: 0.7379
# Epoch 7/100
# 27/27 [==============================] - 1s 24ms/step - loss: 0.5366 - accuracy: 0.7413
# Epoch 8/100
# 27/27 [==============================] - 1s 24ms/step - loss: 0.5283 - accuracy: 0.7472
# Epoch 9/100
# 27/27 [==============================] - 1s 23ms/step - loss: 0.5227 - accuracy: 0.7503
# Epoch 10/100
# 27/27 [==============================] - 1s 22ms/step - loss: 0.5155 - accuracy: 0.7576
# Epoch 11/100
# 27/27 [==============================] - 1s 23ms/step - loss: 0.5105 - accuracy: 0.7579
# Epoch 12/100
# 27/27 [==============================] - 1s 22ms/step - loss: 0.5046 - accuracy: 0.7608
# Epoch 13/100
# 27/27 [==============================] - 1s 22ms/step - loss: 0.5055 - accuracy: 0.7618
# Epoch 14/100
# 27/27 [==============================] - 1s 21ms/step - loss: 0.5003 - accuracy: 0.7644
# Epoch 15/100
# 27/27 [==============================] - 1s 22ms/step - loss: 0.4953 - accuracy: 0.7646
# Epoch 16/100
# 27/27 [==============================] - 1s 21ms/step - loss: 0.4874 - accuracy: 0.7722
# Epoch 17/100
# 27/27 [==============================] - 1s 21ms/step - loss: 0.4890 - accuracy: 0.7732
# Epoch 18/100
# 27/27 [==============================] - 1s 21ms/step - loss: 0.4824 - accuracy: 0.7765
# Epoch 19/100
# 27/27 [==============================] - 1s 34ms/step - loss: 0.4790 - accuracy: 0.7798
# Epoch 20/100
# 27/27 [==============================] - 1s 36ms/step - loss: 0.4807 - accuracy: 0.7801
# Epoch 21/100
# 27/27 [==============================] - 1s 35ms/step - loss: 0.4848 - accuracy: 0.7757
# Epoch 22/100
# 27/27 [==============================] - 1s 35ms/step - loss: 0.4797 - accuracy: 0.7774
# Epoch 23/100
# 27/27 [==============================] - 1s 36ms/step - loss: 0.4776 - accuracy: 0.7830
# Epoch 24/100
# 27/27 [==============================] - 1s 21ms/step - loss: 0.4755 - accuracy: 0.7827
# Epoch 25/100
# 27/27 [==============================] - 1s 21ms/step - loss: 0.4708 - accuracy: 0.7791
# Epoch 26/100
# 27/27 [==============================] - 1s 22ms/step - loss: 0.4733 - accuracy: 0.7793
# Epoch 27/100
# 27/27 [==============================] - 1s 21ms/step - loss: 0.4689 - accuracy: 0.7821
# Epoch 28/100
# 27/27 [==============================] - 1s 21ms/step - loss: 0.4721 - accuracy: 0.7794
# Epoch 29/100
# 27/27 [==============================] - 1s 22ms/step - loss: 0.4664 - accuracy: 0.7858
# Epoch 30/100
# 27/27 [==============================] - 1s 21ms/step - loss: 0.4725 - accuracy: 0.7864
# Epoch 31/100
# 27/27 [==============================] - 1s 21ms/step - loss: 0.4652 - accuracy: 0.7824
# Epoch 32/100
# 27/27 [==============================] - 1s 20ms/step - loss: 0.4664 - accuracy: 0.7807
# Epoch 33/100
# 27/27 [==============================] - 1s 23ms/step - loss: 0.4612 - accuracy: 0.7870
# Epoch 34/100
# 27/27 [==============================] - 1s 21ms/step - loss: 0.4674 - accuracy: 0.7785
# Epoch 35/100
# 27/27 [==============================] - 1s 22ms/step - loss: 0.4617 - accuracy: 0.7879
# Epoch 36/100
# 27/27 [==============================] - 1s 21ms/step - loss: 0.4637 - accuracy: 0.7856
# Epoch 37/100
# 27/27 [==============================] - 1s 21ms/step - loss: 0.4606 - accuracy: 0.7884
# Epoch 38/100
# 27/27 [==============================] - 1s 22ms/step - loss: 0.4591 - accuracy: 0.7853
# Epoch 39/100
# 27/27 [==============================] - 1s 21ms/step - loss: 0.4553 - accuracy: 0.7901
# Epoch 40/100
# 27/27 [==============================] - 1s 21ms/step - loss: 0.4571 - accuracy: 0.7873
# Epoch 41/100
# 27/27 [==============================] - 1s 34ms/step - loss: 0.4557 - accuracy: 0.7909
# Epoch 42/100
# 27/27 [==============================] - 1s 36ms/step - loss: 0.4568 - accuracy: 0.7860
# Epoch 43/100
# 27/27 [==============================] - 1s 36ms/step - loss: 0.4555 - accuracy: 0.7873
# Epoch 44/100
# 27/27 [==============================] - 1s 35ms/step - loss: 0.4584 - accuracy: 0.7910
# Epoch 45/100
# 27/27 [==============================] - 1s 35ms/step - loss: 0.4534 - accuracy: 0.7910
# Epoch 46/100
# 27/27 [==============================] - 1s 21ms/step - loss: 0.4492 - accuracy: 0.7969
# Epoch 47/100
# 27/27 [==============================] - 1s 22ms/step - loss: 0.4554 - accuracy: 0.7886
# Epoch 48/100
# 27/27 [==============================] - 1s 21ms/step - loss: 0.4517 - accuracy: 0.7886
# Epoch 49/100
# 27/27 [==============================] - 1s 22ms/step - loss: 0.4556 - accuracy: 0.7876
# Epoch 50/100
# 27/27 [==============================] - 1s 21ms/step - loss: 0.4573 - accuracy: 0.7906
# Epoch 51/100
# 27/27 [==============================] - 1s 21ms/step - loss: 0.4504 - accuracy: 0.7964
# Epoch 52/100
# 27/27 [==============================] - 1s 21ms/step - loss: 0.4477 - accuracy: 0.7947
# Epoch 53/100
# 27/27 [==============================] - 1s 21ms/step - loss: 0.4426 - accuracy: 0.8007
# Epoch 54/100
# 27/27 [==============================] - 1s 21ms/step - loss: 0.4503 - accuracy: 0.7934
# Epoch 55/100
# 27/27 [==============================] - 1s 21ms/step - loss: 0.4464 - accuracy: 0.7930
# Epoch 56/100
# 27/27 [==============================] - 1s 21ms/step - loss: 0.4435 - accuracy: 0.7953
# Epoch 57/100
# 27/27 [==============================] - 1s 21ms/step - loss: 0.4385 - accuracy: 0.8006
# Epoch 58/100
# 27/27 [==============================] - 1s 22ms/step - loss: 0.4442 - accuracy: 0.7923
# Epoch 59/100
# 27/27 [==============================] - 1s 22ms/step - loss: 0.4460 - accuracy: 0.7972
# Epoch 60/100
# 27/27 [==============================] - 1s 21ms/step - loss: 0.4391 - accuracy: 0.7972
# Epoch 61/100
# 27/27 [==============================] - 1s 21ms/step - loss: 0.4408 - accuracy: 0.8005
# Epoch 62/100
# 27/27 [==============================] - 1s 22ms/step - loss: 0.4410 - accuracy: 0.8005
# Epoch 63/100
# 27/27 [==============================] - 1s 34ms/step - loss: 0.4414 - accuracy: 0.8029
# Epoch 64/100
# 27/27 [==============================] - 1s 36ms/step - loss: 0.4365 - accuracy: 0.8015
# Epoch 65/100
# 27/27 [==============================] - 1s 36ms/step - loss: 0.4323 - accuracy: 0.8035
# Epoch 66/100
# 27/27 [==============================] - 1s 36ms/step - loss: 0.4413 - accuracy: 0.7960
# Epoch 67/100
# 27/27 [==============================] - 1s 35ms/step - loss: 0.4411 - accuracy: 0.8015
# Epoch 68/100
# 27/27 [==============================] - 1s 21ms/step - loss: 0.4400 - accuracy: 0.7983
# Epoch 69/100
# 27/27 [==============================] - 1s 21ms/step - loss: 0.4304 - accuracy: 0.8058
# Epoch 70/100
# 27/27 [==============================] - 1s 22ms/step - loss: 0.4336 - accuracy: 0.8038
# Epoch 71/100
# 27/27 [==============================] - 1s 21ms/step - loss: 0.4348 - accuracy: 0.8059
# Epoch 72/100
# 27/27 [==============================] - 1s 21ms/step - loss: 0.4340 - accuracy: 0.8022
# Epoch 73/100
# 27/27 [==============================] - 1s 22ms/step - loss: 0.4291 - accuracy: 0.8075
# Epoch 74/100
# 27/27 [==============================] - 1s 22ms/step - loss: 0.4320 - accuracy: 0.8030
# Epoch 75/100
# 27/27 [==============================] - 1s 21ms/step - loss: 0.4355 - accuracy: 0.8029
# Epoch 76/100
# 27/27 [==============================] - 1s 21ms/step - loss: 0.4250 - accuracy: 0.8089
# Epoch 77/100
# 27/27 [==============================] - 1s 21ms/step - loss: 0.4308 - accuracy: 0.8062
# Epoch 78/100
# 27/27 [==============================] - 1s 22ms/step - loss: 0.4355 - accuracy: 0.8030
# Epoch 79/100
# 27/27 [==============================] - 1s 20ms/step - loss: 0.4310 - accuracy: 0.8085
# Epoch 80/100
# 27/27 [==============================] - 1s 21ms/step - loss: 0.4285 - accuracy: 0.8065
# Epoch 81/100
# 27/27 [==============================] - 1s 21ms/step - loss: 0.4260 - accuracy: 0.8053
# Epoch 82/100
# 27/27 [==============================] - 1s 21ms/step - loss: 0.4322 - accuracy: 0.8091
# Epoch 83/100
# 27/27 [==============================] - 1s 21ms/step - loss: 0.4290 - accuracy: 0.8059
# Epoch 84/100
# 27/27 [==============================] - 1s 21ms/step - loss: 0.4249 - accuracy: 0.8086
# Epoch 85/100
# 27/27 [==============================] - 1s 35ms/step - loss: 0.4286 - accuracy: 0.8078
# Epoch 86/100
# 27/27 [==============================] - 1s 36ms/step - loss: 0.4271 - accuracy: 0.8040
# Epoch 87/100
# 27/27 [==============================] - 1s 36ms/step - loss: 0.4281 - accuracy: 0.8070
# Epoch 88/100
# 27/27 [==============================] - 1s 37ms/step - loss: 0.4292 - accuracy: 0.8072
# Epoch 89/100
# 27/27 [==============================] - 1s 35ms/step - loss: 0.4309 - accuracy: 0.8058
# Epoch 90/100
# 27/27 [==============================] - 1s 21ms/step - loss: 0.4237 - accuracy: 0.8106
# Epoch 91/100
# 27/27 [==============================] - 1s 21ms/step - loss: 0.4236 - accuracy: 0.8132
# Epoch 92/100
# 27/27 [==============================] - 1s 21ms/step - loss: 0.4300 - accuracy: 0.8030
# Epoch 93/100
# 27/27 [==============================] - 1s 21ms/step - loss: 0.4236 - accuracy: 0.8116
# Epoch 94/100
# 27/27 [==============================] - 1s 21ms/step - loss: 0.4269 - accuracy: 0.8076
# Epoch 95/100
# 27/27 [==============================] - 1s 21ms/step - loss: 0.4264 - accuracy: 0.8066
# Epoch 96/100
# 27/27 [==============================] - 1s 22ms/step - loss: 0.4297 - accuracy: 0.8086
# Epoch 97/100
# 27/27 [==============================] - 1s 20ms/step - loss: 0.4177 - accuracy: 0.8126
# Epoch 98/100
# 27/27 [==============================] - 1s 21ms/step - loss: 0.4190 - accuracy: 0.8102
# Epoch 99/100
# 27/27 [==============================] - 1s 21ms/step - loss: 0.4201 - accuracy: 0.8138
# Epoch 100/100
# 27/27 [==============================] - 1s 21ms/step - loss: 0.4200 - accuracy: 0.8128
# 196/196 [==============================] - 1s 2ms/step - loss: 0.3999 - accuracy: 0.8252
# Test accuracy: 82.52%
